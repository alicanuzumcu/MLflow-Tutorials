# %%
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK,Trials,fmin,hp,tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
## load the dataset
data=pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## Split the data into training,validation and test sets

train,test=train_test_split(data,test_size=0.25,random_state=42)
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
train[['quality']].values.ravel()
# Out:
# array([6, 6, 5, ..., 6, 6, 8], dtype=int64)

# %%
train_x=train.drop(['quality'],axis=1).values
train_y=train[['quality']].values.ravel()

## test dataset
test_x=test.drop(['quality'],axis=1).values
test_y=test[['quality']].values.ravel()

## splitting this train data into train and validation

train_x,valid_x,train_y,valid_y=train_test_split(train_x,train_y,test_size=0.20,random_state=42)

signature=infer_signature(train_x,train_y)

# %%
np.mean(train_x,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
train_x.shape[1]
# Out:
# 11

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(run_name='Deneme', nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 16s 364ms/step - loss: 33.0717 - root_mean_squared_error: 5.7508
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 18.9515 - root_mean_squared_error: 4.2957 - val_loss: 2.9531 - val_root_mean_squared_error: 1.7185
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.7380 - root_mean_squared_error: 1.6547
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4717 - root_mean_squared_error: 1.5709
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4392 - root_mean_squared_error: 1.5605 - val_loss: 2.0259 - val_root_mean_squared_error: 1.4233
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.6363 - root_mean_squared_error: 1.2792
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7416 - root_mean_squared_error: 1.3195
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7450 - root_mean_squared_error: 1.3208 - val_loss: 1.7708 - val_root_mean_squared_error: 1.3307
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.6255 - root_mean_squared_error: 1.2749
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8111 - root_mean_squared_error: 1.3451
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 303ms/step - loss: 32.6139 - root_mean_squared_error: 5.7109
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.4865 - root_mean_squared_error: 5.6111
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 31.4382 - root_mean_squared_error: 5.6068 - val_loss: 29.8346 - val_root_mean_squared_error: 5.4621
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 32.3585 - root_mean_squared_error: 5.6885
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.2589 - root_mean_squared_error: 5.4087
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0164 - root_mean_squared_error: 5.3863 - val_loss: 27.6704 - val_root_mean_squared_error: 5.2603
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 25.2471 - root_mean_squared_error: 5.0246
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.6514 - root_mean_squared_error: 5.1624
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.6322 - root_mean_squared_error: 5.1606 - val_loss: 25.6719 - val_root_mean_squared_error: 5.0667
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 26.1178 - root_mean_squared_error: 5.1106
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6639 - root_mean_squared_error: 5.0659
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 12s 275ms/step - loss: 31.3731 - root_mean_squared_error: 5.6012
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.0437 - root_mean_squared_error: 5.5712 - val_loss: 26.9606 - val_root_mean_squared_error: 5.1924
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 28.0714 - root_mean_squared_error: 5.2982
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25.9047 - root_mean_squared_error: 5.0891
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.5651 - root_mean_squared_error: 5.0554 - val_loss: 22.1172 - val_root_mean_squared_error: 4.7029
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 22.7846 - root_mean_squared_error: 4.7733
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 21.1928 - root_mean_squared_error: 4.6028
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.0797 - root_mean_squared_error: 4.5904 - val_loss: 18.1458 - val_root_mean_squared_error: 4.2598
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 17.7560 - root_mean_squared_error: 4.2138
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.7802 - root_mean_squared_error: 4.2166
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 12s 288ms/step - loss: 37.5148 - root_mean_squared_error: 6.1249
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.5929 - root_mean_squared_error: 5.9659
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 35.5433 - root_mean_squared_error: 5.9617 - val_loss: 34.2895 - val_root_mean_squared_error: 5.8557
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 34.8743 - root_mean_squared_error: 5.9054
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.5107 - root_mean_squared_error: 5.7887
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.4901 - root_mean_squared_error: 5.7869 - val_loss: 32.3664 - val_root_mean_squared_error: 5.6891
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 33.1738 - root_mean_squared_error: 5.7597
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.8127 - root_mean_squared_error: 5.6399
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 31.7461 - root_mean_squared_error: 5.6340 - val_loss: 30.5579 - val_root_mean_squared_error: 5.5279
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 31.4533 - root_mean_squared_error: 5.6083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.6212 - root_mean_squared_error: 5.5336
#
# 100%|██████████| 4/4 [00:36<00:00,  9.24s/trial, best loss: 1.3307101726531982]
# Best parameters: {'lr': 0.0017729863240208332, 'momentum': 0.45329478280527424}
# Best eval rmse: 0.9815323352813721

# %%
## Inferencing

from mlflow.models import validate_serving_input

model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'

# The logged model does not contain an input_example.
# Manually generate a serving payload to verify your model prior to deployment.
from mlflow.models import convert_input_example_to_serving_input

# Define INPUT_EXAMPLE via assignment with your own input example to the model
# A valid input example is a data instance suitable for pyfunc prediction
serving_payload = convert_input_example_to_serving_input(test_x)

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[25], line 16
#      13 serving_payload = convert_input_example_to_serving_input(test_x)
#      15 # Validate the serving payload works on the model
# ---> 16 validate_serving_input(model_uri, serving_payload)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\models\utils.py:1874, in validate_serving_input(model_uri, serving_input)
#    1871 output_dir = None if get_local_path_or_none(model_uri) else create_tmp_dir()
#    1873 try:
# -> 1874     pyfunc_model = mlflow.pyfunc.load_model(model_uri, dst_path=output_dir)
#    1875     parsed_input = _parse_json_data(
#    1876         serving_input,
#    1877         pyfunc_model.metadata,
#    1878         pyfunc_model.metadata.get_input_schema(),
#    1879     )
#    1880     return pyfunc_model.predict(parsed_input.data, params=parsed_input.params)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\tracing\provider.py:309, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     307 disable()
#     308 try:
# --> 309     is_func_called, result = True, f(*args, **kwargs)
#     310 finally:
#     311     enable()
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\pyfunc\__init__.py:1033, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1029         entity_list.append(Entity(job=job_entity))
#    1031     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1033 local_path = _download_artifact_from_uri(
#    1034     artifact_uri=model_uri, output_path=dst_path, lineage_header_info=lineage_header_info
#    1035 )
#    1037 if not suppress_warnings:
#    1038     model_requirements = _get_pip_requirements_from_model_path(local_path)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\tracking\artifact_utils.py:108, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     100 """
#     101 Args:
#     102     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     105     lineage_header_info: The model lineage header info to be consumed by lineage services.
#     106 """
#     107 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:131, in get_artifact_repository(artifact_uri)
#     118 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     119     """
#     120     Get an artifact repository from the registry based on the scheme of artifact_uri
#     121
#    (...)
#     129         requirements.
#     130     """
# --> 131     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:76, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      71 if repository is None:
#      72     raise MlflowException(
#      73         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      74         f"Currently registered schemes are: {list(self._registry.keys())}"
#      75     )
# ---> 76 return repository(artifact_uri)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:26, in RunsArtifactRepository.__init__(self, artifact_uri)
#      23 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      25 super().__init__(artifact_uri)
# ---> 26 uri = RunsArtifactRepository.get_underlying_uri(artifact_uri)
#      27 self.repo = get_artifact_repository(uri)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\artifact\runs_artifact_repo.py:39, in RunsArtifactRepository.get_underlying_uri(runs_uri)
#      37 (run_id, artifact_path) = RunsArtifactRepository.parse_runs_uri(runs_uri)
#      38 tracking_uri = get_databricks_profile_uri_from_artifact_uri(runs_uri)
# ---> 39 uri = get_artifact_uri(run_id, artifact_path, tracking_uri)
#      40 assert not RunsArtifactRepository.is_runs_uri(uri)  # avoid an infinite loop
#      41 return add_databricks_profile_info_to_artifact_uri(uri, tracking_uri)
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\tracking\artifact_utils.py:52, in get_artifact_uri(run_id, artifact_path, tracking_uri)
#      46     raise MlflowException(
#      47         message="A run_id must be specified in order to obtain an artifact uri!",
#      48         error_code=INVALID_PARAMETER_VALUE,
#      49     )
#      51 store = _get_store(tracking_uri)
# ---> 52 run = store.get_run(run_id)
#      53 # Maybe move this method to RunsArtifactRepository so the circular dependency is clearer.
#      54 assert urllib.parse.urlparse(run.info.artifact_uri).scheme != "runs"  # avoid an infinite loop
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\tracking\file_store.py:694, in FileStore.get_run(self, run_id)
#     690 """
#     691 Note: Will get both active and deleted runs.
#     692 """
#     693 _validate_run_id(run_id)
# --> 694 run_info = self._get_run_info(run_id)
#     695 if run_info is None:
#     696     raise MlflowException(
#     697         f"Run '{run_id}' metadata is in invalid state.",
#     698         databricks_pb2.INVALID_STATE,
#     699     )
#
# File c:\Users\ALI CAN\Desktop\MLops\MLflow\venv\lib\site-packages\mlflow\store\tracking\file_store.py:719, in FileStore._get_run_info(self, run_uuid)
#     717 exp_id, run_dir = self._find_run_root(run_uuid)
#     718 if run_dir is None:
# --> 719     raise MlflowException(
#     720         f"Run '{run_uuid}' not found", databricks_pb2.RESOURCE_DOES_NOT_EXIST
#     721     )
#     722 run_info = self._get_run_info_from_dir(run_dir)
#     723 if run_info.experiment_id != exp_id:
#
# MlflowException: Run '9e0b52639ab44e6a864f5bd2f460fe42' not found

# %%
# Load model as a PyFuncModel.
model_uri = 'runs:/9e0b52639ab44e6a864f5bd2f460fe42/model'
loaded_model = mlflow.pyfunc.load_model(model_uri)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(test_x))
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[4.2569876],
#        [7.2708473],
#        [5.690359 ],
#        ...,
#        [6.881361 ],
#        [6.6991577],
#        [4.748927 ]], dtype=float32)

# %%
## Register in the model registry
mlflow.register_model(model_uri,"wine-quality")
# Out:
# Successfully registered model 'wine-quality'.
# Created version '1' of model 'wine-quality'.
# <ModelVersion: aliases=[], creation_timestamp=1727548664831, current_stage='None', description=None, last_updated_timestamp=1727548664831, name='wine-quality', run_id='9e0b52639ab44e6a864f5bd2f460fe42', run_link=None, source='file:///e:/UDemy%20Final/MlFlowStarter/2-DLMLFLOW/mlruns/929139454095764868/9e0b52639ab44e6a864f5bd2f460fe42/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=1>
